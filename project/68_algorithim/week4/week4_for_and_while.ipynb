# %%
runnnig = 10
for i in range(runnnig):
    print("Round is :", i)
# Out:
# Round is : 0
# Round is : 1
# Round is : 2
# Round is : 3
# Round is : 4
# Round is : 5
# Round is : 6
# Round is : 7
# Round is : 8
# Round is : 9

# %%
check = True 
while(check):
    print("check")
    check = False
# Out:
# check

# %%
runnnig_str = input("จำนวนรอบที่ต้องการวิ่ง : ")
runnnig_int = int(runnnig_str)

for i in range(runnnig_int):
    print("รอบที่ :", i+1)
# Out:
# รอบที่ : 1
# รอบที่ : 2
# รอบที่ : 3
# รอบที่ : 4
# รอบที่ : 5
# รอบที่ : 6
# รอบที่ : 7
# รอบที่ : 8
# รอบที่ : 9
# รอบที่ : 10

# %%
state = input("สั่งให้เริ่มวิ่ง ด้วยคำสั่ง 1 ")
if(state == '1'):
    state_runnning = True
else:
    state_runnning = False 
i = 1
while(state):
    print("Ronud :",i)
    i = i + 1
    interrup = input("ต้องการหยุดหรือไม่ 1 หยุด  หรือ 0 ไม่หยุด")
    if(interrup == '1'):
        state = True
    elif(interrup == '0'):
        state = False
# Out:
# Ronud : 1
# Ronud : 2
# Ronud : 3
# Ronud : 4
# Ronud : 5
# Ronud : 6
# Ronud : 7
# Ronud : 8
# Ronud : 9
# Ronud : 10
# Ronud : 11
# Ronud : 12
# Ronud : 13
# Ronud : 14
# Ronud : 15
# Ronud : 16

# %%
Q = "Press = exit"
M = "Press = Main"
S = "Press = Start in Program"
state = True
while(state):
    print(Q)
    print(M)
    print(S)

    inp = input("Menu Selected :")
    if(inp == 'Q'):
        state = False
    elif(inp == 'M'):
        print("Home Menu")
    elif(inp == 'S'):
        runnnig_str = input("จำนวนรอบที่ต้องการวิ่ง : ")
        runnnig_int = int(runnnig_str)
        for i in range (runnnig_int):
            print("รอบที่ :", i+1)
    else:
        print("Home Menu")
# Out:
# Press = exit
# Press = Main
# Press = Start in Program
# รอบที่ : 1
# รอบที่ : 2
# รอบที่ : 3
# รอบที่ : 4
# รอบที่ : 5
# รอบที่ : 6
# รอบที่ : 7
# รอบที่ : 8
# รอบที่ : 9
# รอบที่ : 10
# Press = exit
# Press = Main
# Press = Start in Program
